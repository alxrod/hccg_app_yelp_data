# %%
import requests
import json

# %%
def get_menu_items():
    url = 'https://www.thecheesecakefactory.com/menu/'
    raw = requests.get(url).text
    raw = raw[raw.find('<div class="food-menu-panel'):]
    while raw.find('<a href="') != -1:
        raw = raw[len('<a href="'):]
        end = raw.find('"')
        print("Test!")
        print(raw[len('<a href="'):end])
        raw = raw[end+1:]

# %%
get_menu_items()
# Out:
# Test!
#
# Test!
#
# Test!
# s=
# Test!
# -title food-panel-results-title
# Test!
# 				</div>
# 						<div class=
# Test!
#
# Test!
# s=
# Test!
# -wrapper
# Test!
# ss=
# Test!
# -title food-panel-categories-title
# Test!
# iv>
# 								<div class=
# Test!
# -title food-panel-subcategories-title
# Test!
# 							<div class=
# Test!
# -title food-panel-subsubcategories-title
# Test!
# 						</div>
# 						</div>
# 						<div class=
# Test!
#
# Test!
# s=
# Test!
# -title food-panel-listings-title
# Test!
# 				</div>
# 						<div class=
# Test!
#
# Test!
# s=
# Test!
# -title food-panel-detail-title
# Test!
# 				</div>
# 					</div>
# 					<div class=
# Test!
# -description
# Test!
# ore than 250 dishes made fresh from scratch every day</p>					</div>
# 				</div>
# 			</div>
# 			<div id=
# Test!
#
# Test!
# wrapper
# Test!
#
# Test!
# od-panel-results
# Test!
#
# Test!
#
# Test!
#
# Test!
#
# Test!
# 	</div>
# 				</div>
# 				<div class=
# Test!
# od-panel-categories
# Test!
#
# ...
